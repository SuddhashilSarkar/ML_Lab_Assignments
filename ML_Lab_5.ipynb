# %% [markdown]
# <a href="https://colab.research.google.com/github/SuddhashilSarkar/ML_Lab_Assignments/blob/main/ML_Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Define the data
data = {
    'Date': [
        '10-01-16', '10-02-16', '10-03-16', '10-04-16', '10-05-16',
        '10-06-16', '10-07-16', '10-08-16', '10-09-16', '10-10-16'
    ],
    'Open': [
        770.25, 776.030029, 774.25, 776.030029, 779.3541998,
        776.306698, 779.659973, 776.309998, 775.554009, 776.432029
    ],
    'High': [
        776.075902, 778.730022, 776.065702, 771.710022, 782.073407,
        782.46398, 779.659973, 782.070007, 785.42138, 778.730022
    ],
    'Low': [
        769.5, 780.890015, 766.5, 772.890015, 775.650024,
        775.539978, 770.75, 775.650024, 775.54478, 780.890015
    ],
    'Close': [
        782.659998, 776.429993, 772.549798, 776.429993, 776.469971,
        776.859985, 775.080017, 776.469971, 776.859985, 776.429993
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Convert 'Date' to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')

# Extract month and year
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# Example: Filter data for a specific month and year
month_to_filter = 10  # October
year_to_filter = 2016
filtered_df = df[(df['Month'] == month_to_filter) & (df['Year'] == year_to_filter)]

# Display the DataFrame with the new columns and filtered data
print("DataFrame with Month and Year columns:")
print(df)
print("\nFiltered DataFrame for October 2016:")
print(filtered_df)
# Out:
# DataFrame with Month and Year columns:
#         Date        Open        High         Low       Close  Month  Year
# 0 2016-10-01  770.250000  776.075902  769.500000  782.659998     10  2016
# 1 2016-10-02  776.030029  778.730022  780.890015  776.429993     10  2016
# 2 2016-10-03  774.250000  776.065702  766.500000  772.549798     10  2016
# 3 2016-10-04  776.030029  771.710022  772.890015  776.429993     10  2016
# 4 2016-10-05  779.354200  782.073407  775.650024  776.469971     10  2016
# 5 2016-10-06  776.306698  782.463980  775.539978  776.859985     10  2016
# 6 2016-10-07  779.659973  779.659973  770.750000  775.080017     10  2016
# 7 2016-10-08  776.309998  782.070007  775.650024  776.469971     10  2016
# 8 2016-10-09  775.554009  785.421380  775.544780  776.859985     10  2016
# 9 2016-10-10  776.432029  778.730022  780.890015  776.429993     10  2016
#
# Filtered DataFrame for October 2016:
#         Date        Open        High         Low       Close  Month  Year
# ...

# %%
# prompt: Write a Python program to visualize the data from the filtered_df
# a) Line Chart , b) Bar Graph c) Histogram
# show legends and different colours.

import matplotlib.pyplot as plt

# a) Line Chart
plt.figure(figsize=(10, 6))
plt.plot(filtered_df['Date'], filtered_df['Open'], label='Open', color='blue')
plt.plot(filtered_df['Date'], filtered_df['Close'], label='Close', color='red')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Open and Close Prices for October 2016')
plt.legend()
plt.grid(True)
plt.show()

# b) Bar Graph
plt.figure(figsize=(10, 6))
plt.bar(filtered_df['Date'], filtered_df['High'] - filtered_df['Low'], label='Daily Range', color='green')
plt.xlabel('Date')
plt.ylabel('Price Range')
plt.title('Daily Price Range for October 2016')
plt.legend()
plt.grid(True)
plt.show()

# c) Histogram
plt.figure(figsize=(10, 6))
plt.hist(filtered_df['Close'], bins=10, label='Close Prices', color='purple', alpha=0.7)
plt.xlabel('Closing Price')
plt.ylabel('Frequency')
plt.title('Distribution of Closing Prices for October 2016')
plt.legend()
plt.grid(True)
plt.show()

# %%
# prompt: Read all columns of the filtered_df and show it using a multiline plot

import matplotlib.pyplot as plt
# Plot all columns of the filtered DataFrame
plt.figure(figsize=(10, 6))
for column in filtered_df.columns:
  if column != 'Date':
    plt.plot(filtered_df['Date'], filtered_df[column], label=column)

plt.xlabel('Date')
plt.ylabel('Value')
plt.title('All Columns of Filtered DataFrame')
plt.legend()
plt.grid(True)
plt.show()

# %%
# prompt: Read the Open column values from dataframe of each month and show it using a scatter
# plot

import pandas as pd
import matplotlib.pyplot as plt

# Extract the 'Open' column values
open_values = df['Open']

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Date'], open_values, label='Open', color='blue', marker='o')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Scatter Plot of Open Prices')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# prompt: Read Open and Close columns values from filtered_df of each month and plot it dide by side in a barchart with different legends and colours

import pandas as pd
import matplotlib.pyplot as plt

# ... (Preceding code remains the same)

# Group the data by month and extract Open and Close values
monthly_data = filtered_df.groupby('Month')[['Open', 'Close']].mean()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(monthly_data.index - 0.2, monthly_data['Open'], width=0.4, label='Open', color='blue')
plt.bar(monthly_data.index + 0.2, monthly_data['Close'], width=0.4, label='Close', color='red')
plt.xlabel('Month')
plt.ylabel('Average Price')
plt.title('Average Open and Close Prices for October 2016')
plt.xticks(monthly_data.index, ['October'])  # Set x-axis labels to month names
plt.legend()
plt.grid(True)
plt.show()

# %%
# prompt: Read the High and Low columns values from filtered_df of all months and show it using a
# bar chart

import matplotlib.pyplot as plt
# Group the data by month and extract High and Low values
monthly_data = df.groupby('Month')[['High', 'Low']].mean()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(monthly_data.index - 0.2, monthly_data['High'], width=0.4, label='High', color='blue')
plt.bar(monthly_data.index + 0.2, monthly_data['Low'], width=0.4, label='Low', color='red')
plt.xlabel('Month')
plt.ylabel('Average Price')
plt.title('Average High and Low Prices by Month')
plt.xticks(monthly_data.index, ['October'])  # Set x-axis labels to month names
plt.legend()
plt.grid(True)
plt.show()

# %%
# prompt: Read the Close column values of each month and display using proper labels :
# a) Histogram to see the most common profit ranges
# b) BarChart to see the most common profit ranges
# c) Pie Chart
# Use filtered_df

import matplotlib.pyplot as plt
# a) Histogram
plt.figure(figsize=(10, 6))
plt.hist(filtered_df['Close'], bins=10, label='Close Prices', color='skyblue', edgecolor='black')
plt.xlabel('Closing Price')
plt.ylabel('Frequency')
plt.title('Distribution of Closing Prices for October 2016')
plt.legend()
plt.grid(True)
plt.show()

# b) Bar Chart
close_counts = filtered_df['Close'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(close_counts.index, close_counts.values, color='lightcoral', edgecolor='black')
plt.xlabel('Closing Price')
plt.ylabel('Frequency')
plt.title('Frequency of Closing Prices for October 2016')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# c) Pie Chart
plt.figure(figsize=(8, 8))
plt.pie(close_counts.values, labels=close_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Proportion of Closing Prices for October 2016')
plt.show()

# %%
# prompt: For the Open Columns Data from the filtered_df and show it using a Pie chart.

import matplotlib.pyplot as plt
# Extract the 'Open' column values from the filtered DataFrame
open_values = filtered_df['Open']

# Count the frequency of each open price
open_counts = open_values.value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(open_counts.values, labels=open_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Proportion of Open Prices for October 2016')
plt.show()

# %% [markdown]
# **Alternate combined solution**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the data
data = {
    'Date': [
        '10-01-16', '10-02-16', '10-03-16', '10-04-16', '10-05-16',
        '10-06-16', '10-07-16', '10-08-16', '10-09-16', '10-10-16'
    ],
    'Open': [
        770.25, 776.030029, 774.25, 776.030029, 779.3541998,
        776.306698, 779.659973, 776.309998, 775.554009, 776.432029
    ],
    'High': [
        776.075902, 778.730022, 776.065702, 771.710022, 782.073407,
        782.46398, 779.659973, 782.070007, 785.42138, 778.730022
    ],
    'Low': [
        769.5, 780.890015, 766.5, 772.890015, 775.650024,
        775.539978, 770.75, 775.650024, 775.54478, 780.890015
    ],
    'Close': [
        782.659998, 776.429993, 772.549798, 776.429993, 776.469971,
        776.859985, 775.080017, 776.469971, 776.859985, 776.429993
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Convert 'Date' to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')

# 1. Visualization of the data
plt.figure(figsize=(14, 8))

# a) Line Chart
plt.subplot(3, 1, 1)
plt.plot(df['Date'], df['Open'], marker='o', color='blue', label='Open')
plt.plot(df['Date'], df['High'], marker='o', color='green', label='High')
plt.plot(df['Date'], df['Low'], marker='o', color='red', label='Low')
plt.plot(df['Date'], df['Close'], marker='o', color='purple', label='Close')
plt.title('Line Chart of Stock Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

# b) Bar Graph
plt.subplot(3, 1, 2)
bar_width = 0.2
x = df['Date']
plt.bar(x - pd.DateOffset(days=5), df['Open'], width=bar_width, color='blue', label='Open')
plt.bar(x, df['High'], width=bar_width, color='green', label='High')
plt.bar(x + pd.DateOffset(days=5), df['Low'], width=bar_width, color='red', label='Low')
plt.bar(x + pd.DateOffset(days=10), df['Close'], width=bar_width, color='purple', label='Close')
plt.title('Bar Graph of Stock Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.xticks(rotation=45)

# c) Histogram
plt.subplot(3, 1, 3)
plt.hist(df['Open'], bins=5, alpha=0.5, color='blue', label='Open')
plt.hist(df['Close'], bins=5, alpha=0.5, color='purple', label='Close')
plt.title('Histogram of Stock Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# 2. Multiline Plot for all columns
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Open'], marker='o', color='blue', label='Open')
plt.plot(df['Date'], df['High'], marker='o', color='green', label='High')
plt.plot(df['Date'], df['Low'], marker='o', color='red', label='Low')
plt.plot(df['Date'], df['Close'], marker='o', color='purple', label='Close')
plt.title('Multiline Plot of Stock Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Convert PeriodIndex to string for plotting
months = monthly_open.index.astype(str)

plt.figure(figsize=(10, 6))
plt.scatter(months, monthly_open.values, color='blue', label='Open')
plt.title('Scatter Plot of Monthly Open Prices')
plt.xlabel('Month')
plt.ylabel('Open Price')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# 4. Bar Chart for Open and Close columns values of each month
# Convert 'Date' to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')

# Add Month column
df['Month'] = df['Date'].dt.to_period('M')

# 4. Bar Chart for Open and Close columns values of each month
monthly_data = df.groupby('Month')[['Open', 'Close']].mean()

plt.figure(figsize=(12, 6))
width = 0.4
index = range(len(monthly_data))

plt.bar(index, monthly_data['Open'], width=width, color='blue', label='Open')
plt.bar([i + width for i in index], monthly_data['Close'], width=width, color='purple', label='Close')

plt.xlabel('Month')
plt.ylabel('Price')
plt.title('Monthly Open and Close Prices')
plt.xticks([i + width / 2 for i in index], monthly_data.index.astype(str), rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# 5. Bar Chart for High and Low columns values of all months
plt.figure(figsize=(12, 6))
plt.bar(df['Date'] - pd.DateOffset(days=5), df['High'], width=bar_width, color='green', label='High')
plt.bar(df['Date'] + pd.DateOffset(days=5), df['Low'], width=bar_width, color='red', label='Low')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('High and Low Prices')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# 6. Close column values
# a) Histogram
plt.figure(figsize=(12, 6))
plt.hist(df['Close'], bins=5, color='purple', label='Close', alpha=0.7)
plt.title('Histogram of Close Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# b) Bar Chart
plt.figure(figsize=(12, 6))
close_counts = df['Close'].value_counts().sort_index()
plt.bar(close_counts.index, close_counts.values, color='purple', label='Close')
plt.title('Bar Chart of Close Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# c) Pie Chart
plt.figure(figsize=(8, 8))
plt.pie(close_counts, labels=close_counts.index, autopct='%1.1f%%', colors=plt.cm.Paired(range(len(close_counts))), startangle=140)
plt.title('Pie Chart of Close Prices')
plt.tight_layout()
plt.show()

# 7. Pie Chart for Open column
plt.figure(figsize=(8, 8))
open_counts = df['Open'].value_counts().sort_index()
plt.pie(open_counts, labels=open_counts.index, autopct='%1.1f%%', colors=plt.cm.Paired(range(len(open_counts))), startangle=140)
plt.title('Pie Chart of Open Prices')
plt.tight_layout()
plt.show()
